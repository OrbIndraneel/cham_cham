# %%
from risk_engine import compute_risk_level

my_zone = {
    "Rainfall_mm": 320, "Temperature_C": 29, "Humidity_pct": 85,
    "River_Discharge_m3s": 610, "Water_Level_m": 4.2, "Elevation_m": 45,
    "Land_Cover": "Urban", "Soil_Type": "Clay",
    "Population_Density": 1200, "Infrastructure": 1, "Historical_Floods": 1
}
compute_risk_level(my_zone)
# Out:
# {'flood_probability': 0.915,
#  'risk_score': 0.83,
#  'risk_level': 'Critical',
#  'factors': {'population_density_factor': 0.6,
#   'elevation_factor': 0.91,
#   'historical_floods_factor': 1.0,
#   'infrastructure_factor': 0.0}}

# %%
pip install scikit-learn==1.8.0
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/8.0 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.0 MB ? eta -:--:--
#    ------- -------------------------------- 1.6/8.0 MB 6.1 MB/s eta 0:00:02
#    ----------------- ---------------------- 3.4/8.0 MB 7.2 MB/s eta 0:00:01
#    -------------------------- ------------- 5.2/8.0 MB 7.6 MB/s eta 0:00:01
#    -------------------------- ------------- 5.2/8.0 MB 7.6 MB/s eta 0:00:01
#    -------------------------- ------------- 5.2/8.0 MB 7.6 MB/s eta 0:00:01
#    -------------------------- ------------- 5.2/8.0 MB 7.6 MB/s eta 0:00:01
#    -------------------------- ------------- 5.2/8.0 MB 7.6 MB/s eta 0:00:01
#    ------------------------------- -------- 6.3/8.0 MB 3.5 MB/s eta 0:00:01
#    ----------------------------------- ---- 7.1/8.0 MB 3.5 MB/s eta 0:00:01
# ...

# %%
from resource_engine import get_emergency_resources

result = get_emergency_resources(22.310, 73.180)
print(result)
# Out:
# {'recommended_ambulance': {'ambulance_id': 'A01', 'distance_km': 0.1, 'eta_min': 8, 'route_status': 'Clear'}, 'recommended_hospital': {'hospital_id': 'H04', 'hospital_name': 'Government District Hospital', 'distance_km': 2.28, 'beds_available': 40, 'capacity_pct': 45, 'route_status': 'Clear'}}
